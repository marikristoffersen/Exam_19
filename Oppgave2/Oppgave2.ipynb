# %%
import pandas as pd
#import packages as pandas
import numpy as  np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
#allow graphs

# %%
import os 
df = open(os.path.expanduser("~/Desktop/studmepsinsurance_clean3010.xlsx"))
df = pd.read_excel(r'~/Desktop/studmepsinsurance_clean3010.xlsx')

# %%
df.head(10)
# Out:
#        id  adsmok42 adsmok42_clean  age53x  angidx angidx_clean  cancerdx  \
# 0  349388      -1.0                     12     NaN                    NaN
# 1  270909       2.0              0      23     NaN                    NaN
# 2  292654      -1.0                     13     NaN                    NaN
# 3  464088       1.0              1      56     2.0            0       2.0
# 4  137824       2.0              0      31     NaN                    NaN
# 5  425178       2.0              0      67     2.0            0       2.0
# 6  267554       2.0              0      39     NaN                    NaN
# 7  429814       2.0              0      21     2.0            0       2.0
# 8  282902       1.0              1      58     NaN                    NaN
# 9  137394       2.0              0      50     NaN                    NaN
#
#   cancerdx_clean  chddx chddx_clean  ... inh113  inh121 inh129  inh138  \
# 0                   NaN              ...      1       2      2       2
# ...

# %%
df.race_clean.describe()
# Out:
# count     10000
# unique        2
# top       White
# freq       7590
# Name: race_clean, dtype: object

# %%
df.race_clean.value_counts()
# Out:
# White    7590
# Other    2410
# Name: race_clean, dtype: int64

# %%
df.sex_clean.value_counts()
# Out:
# Female    5234
# Male      4766
# Name: sex_clean, dtype: int64

# %%
df.sex_clean.describe()
# Out:
# count      10000
# unique         2
# top       Female
# freq        5234
# Name: sex_clean, dtype: object

# %%
import statsmodels.formula.api as smf

# %%
model = 'totexp ~ + sex_clean + unins_clean + race_clean + adsmok42_clean + age53x'
regression = smf.ols(formula=model, data=df).fit()
regression.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 totexp   R-squared:                       0.057
# Model:                            OLS   Adj. R-squared:                  0.057
# Method:                 Least Squares   F-statistic:                     96.65
# Date:                Thu, 31 Oct 2019   Prob (F-statistic):          2.19e-118
# Time:                        14:51:48   Log-Likelihood:                -99773.
# No. Observations:                9517   AIC:                         1.996e+05
# Df Residuals:                    9510   BIC:                         1.996e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %%
df.unins_clean.describe()
# Out:
# count        9517
# unique          2
# top       Insured
# freq         8016
# Name: unins_clean, dtype: object

# %%
df.unins_clean = df.unins_clean.replace('Insured', 0)
df.unins_clean = df.unins_clean.replace('Uninsured', 1)

# %%
model = 'unins_clean ~ race_clean + cancerdx_clean + sex_clean + age53x'
propensity = smf.logit(formula=model, data = df).fit()
propensity.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.429541
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:            unins_clean   No. Observations:                 9517
# Model:                          Logit   Df Residuals:                     9511
# Method:                           MLE   Df Model:                            5
# Date:                Thu, 31 Oct 2019   Pseudo R-squ.:                 0.01451
# Time:                        14:52:11   Log-Likelihood:                -4087.9
# converged:                       True   LL-Null:                       -4148.1
# Covariance Type:            nonrobust   LLR p-value:                 2.602e-24
# ...
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
df['propensity'] = propensity.predict()
df.groupby('unins_clean')['propensity'].hist(alpha=0.4);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-23598b8b7c50> in <module>
# ----> 1 df['propensity'] = propensity.predict()
#       2 df.groupby('unins_clean')['propensity'].hist(alpha=0.4);
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3443
#    3444         self._ensure_valid_index(value)
# -> 3445         value = self._sanitize_column(key, value)
#    3446         NDFrame._set_item(self, key, value)
#    3447
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3628
# ...
